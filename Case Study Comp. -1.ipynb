# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("Inverter Data.csv")
df['Inverter 1'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
plt.plot(df['Inverter 1'])
